# %%
import torch
from seta import (
    MLPThinker, GNNThinker,
    System,
    Dynamics,
    Simulator,
    CustomFunctionDataset, OfflineRBFInterpolationDataset,
    Environment,
    Trainer)

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# params

T_max= 100
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# DATASET
import pickle
import numpy as np

# Load the RBF interpolation from the file
with open('rbf_interpolation_internodes.pkl', 'rb') as f:
    rbf_loaded = pickle.load(f)


def curve_data(time_tensor: torch.Tensor, temperature: float) -> torch.Tensor:
    pred = []
    for el in time_tensor:
        pred.append(torch.tensor(rbf_loaded(np.array([el.item(),temperature]).reshape(1,-1))).float())
    return torch.cat(pred, dim=0)



num_examples = 80
temp_min = 20.0
temp_max = 40.0

dataset = CustomFunctionDataset(
    T=T_max,
    num_examples=num_examples,
    temp_min=temp_min,
    temp_max=temp_max,
    curve_fn=curve_data
)


dataset = OfflineRBFInterpolationDataset("dataset_offline.npz")
# Out:
# Building Dataset

# %%
# SYSTEM

system = System(device=device)


decision_net = GNNThinker(device = device)

dyn = Dynamics()

def STEM_rule(agent, system):
        """
        For a WorkerAgent:
          - increase 'workload' by 0.1 each step
          - if system.temperature > 20, increase 'age' by an extra 0.5
        """
        # agent.state is a WorkerState dataclass with fields (age, workload)
        agent.state.size += 0.1
        

def LEAF_rule(agent, system):
        """
        For a WorkerAgent:
          - increase 'workload' by 0.1 each step
          - if system.temperature > 20, increase 'age' by an extra 0.5
        """
        # agent.state is a WorkerState dataclass with fields (age, workload)
        agent.state.size += 0.1
        


dyn.register_rule("S", STEM_rule)
dyn.register_rule("L", LEAF_rule)


def spawn_node_SAM(system, prediction):
        current_W = system.types.count("S")
        delta = prediction - current_W
        if delta > 0.0:
            n_to_spawn = int(torch.ceil(torch.tensor(delta)).item())
            for _ in range(n_to_spawn):
                system.add_node_SAM()

sim = Simulator(
     T_max=T_max,
     system=system,
     system_dynamic= dyn,
     decision_net=decision_net,
     act_rule=spawn_node_SAM,
     device= device
    )

# %%
# ─── Training Configuration ──────────────────────────────────────────
    
epochs = 100
batch_size = 8
learning_rate = 1e-2

output_model_path = "decision_net_GNN.pth"

validation_split = 0.2
patience = 10
curve_interval = 25
num_example_curves = 4

    # 4) Train
trainer = Trainer(
    decision_net=decision_net,
    simulator=sim,
    dataset=dataset,
    device=device,
    num_epochs=epochs,
    batch_size=batch_size,
    lr=learning_rate,
    validation_split=validation_split,
    patience=patience,
    visualize=True,
    curve_interval=curve_interval,
    num_example_curves=num_example_curves,
    output_model_path=output_model_path
)
trainer.train()
# Out:
# Starting training (patience=10 epochs) …
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 30
#      14     # 4) Train
#      15 trainer = Trainer(
#      16     decision_net=decision_net,
#      17     simulator=sim,
#    (...)
#      28     output_model_path=output_model_path
#      29 )
# ---> 30 trainer.train()
#
# File c:\Users\leobr\Desktop\SETA\seta\trainers\trainer.py:116, in Trainer.train(self)
#     114     env_i = envs_batch[i]
#     115     env = Environment(env_i)
# --> 116     pred_curve_i = self.simulator.run(env, "train", 0)    # Tensor (T,)
#     117     batch_preds.append(pred_curve_i.unsqueeze(0))  # shape (1, T)
#     119 # t0 = time.time()
#
# File c:\Users\leobr\Desktop\SETA\seta\core\simulation.py:147, in Simulator.run(self, environment, mode, verbose, output)
#     144     print(f"[t={t}] Phase 3 (Think)")
#     146 t0 = time.time()
# --> 147 pred = self.decision_net.forward(system=self.system, t=t)
#     148 preds_run.append(pred)
#     149 phase_times["think"] += time.time() - t0
#
# File c:\Users\leobr\Desktop\SETA\seta\thinkers\thinkers.py:60, in ThinkerBase.forward(self, system, t)
#      58 # If extract_features returned a tuple (for GNN), unpack it
#      59 if isinstance(feats, tuple):
# ---> 60     raw = self.net(*[f.to(self.device) for f in feats])
#      61 else:
#      62     raw = self.net(feats.to(self.device))
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\leobr\Desktop\SETA\seta\thinkers\thinkers.py:288, in _GNNWrapper.forward(self, node_feats, edge_index, batch, temperature, t)
#     286 h = node_feats.view(-1, 2)  # assume state_dim=1 (only 'age'); if more dims, adjust accordingly
#     287 for conv in self.convs:
# --> 288     h = conv(h, edge_index)
#     289     h = nn.functional.relu(h)
#     290 pooled = self.global_pool(h, batch)  # (1, hidden_dim)
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch_geometric\nn\conv\sage_conv.py:135, in SAGEConv.forward(self, x, edge_index, size)
#     133 # propagate_type: (x: OptPairTensor)
#     134 out = self.propagate(edge_index, x=x, size=size)
# --> 135 out = self.lin_l(out)
#     137 x_r = x[1]
#     138 if self.root_weight and x_r is not None:
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\leobr\anaconda3\envs\tesi\Lib\site-packages\torch_geometric\nn\dense\linear.py:147, in Linear.forward(self, x)
#     141 def forward(self, x: Tensor) -> Tensor:
#     142     r"""Forward pass.
#     143
#     144     Args:
#     145         x (torch.Tensor): The input features.
#     146     """
# --> 147     return F.linear(x, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (4x2 and 1x32)

# %%
# test 

model_path = "decision_net.pth"
decision_net.load_state_dict(torch.load(model_path, map_location=device))

env_test = Environment(25)
sim.T_max = 60
sim.run(env_test,"train",3, output = "out/")
# Out:
# === Starting simulation - Mode: train ===
# [t=0] Phase 1 (Sense)
# [t=0] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.1}
#     Node 1 (L): {'age': 0.0, 'size': 0.2}
#     Node 2 (L): {'age': 0.0, 'size': 0.2}
#     Node 3 (SAM): {'age': 0.0}
# [t=0] Phase 3 (Think)
# [t=0] Phase 4 (Act)
# C:\Users\leobr\AppData\Local\Temp\ipykernel_9248\669228694.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   n_to_spawn = int(torch.ceil(torch.tensor(delta)).item())
# [t=1] Phase 1 (Sense)
# [t=1] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 2 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.1}
#     Node 5 (L): {'age': 0.0, 'size': 0.2}
#     Node 6 (L): {'age': 0.0, 'size': 0.2}
#     Node 7 (S): {'age': 0.0, 'size': 1.1}
#     Node 8 (L): {'age': 0.0, 'size': 0.2}
#     Node 9 (L): {'age': 0.0, 'size': 0.2}
# [t=1] Phase 3 (Think)
# [t=1] Phase 4 (Act)
# [t=2] Phase 1 (Sense)
# [t=2] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 1 (L): {'age': 0.0, 'size': 0.4}
#     Node 2 (L): {'age': 0.0, 'size': 0.4}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 6 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 7 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 9 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=2] Phase 3 (Think)
# [t=2] Phase 4 (Act)
# [t=3] Phase 1 (Sense)
# [t=3] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 1 (L): {'age': 0.0, 'size': 0.5}
#     Node 2 (L): {'age': 0.0, 'size': 0.5}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 5 (L): {'age': 0.0, 'size': 0.4}
#     Node 6 (L): {'age': 0.0, 'size': 0.4}
#     Node 7 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 8 (L): {'age': 0.0, 'size': 0.4}
#     Node 9 (L): {'age': 0.0, 'size': 0.4}
# [t=3] Phase 3 (Think)
# [t=3] Phase 4 (Act)
# [t=4] Phase 1 (Sense)
# [t=4] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 1 (L): {'age': 0.0, 'size': 0.6}
#     Node 2 (L): {'age': 0.0, 'size': 0.6}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 5 (L): {'age': 0.0, 'size': 0.5}
#     Node 6 (L): {'age': 0.0, 'size': 0.5}
#     Node 7 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 8 (L): {'age': 0.0, 'size': 0.5}
#     Node 9 (L): {'age': 0.0, 'size': 0.5}
#     Node 10 (S): {'age': 0.0, 'size': 1.1}
#     Node 11 (L): {'age': 0.0, 'size': 0.2}
#     Node 12 (L): {'age': 0.0, 'size': 0.2}
# [t=4] Phase 3 (Think)
# [t=4] Phase 4 (Act)
# [t=5] Phase 1 (Sense)
# [t=5] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 1 (L): {'age': 0.0, 'size': 0.7}
#     Node 2 (L): {'age': 0.0, 'size': 0.7}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 5 (L): {'age': 0.0, 'size': 0.6}
#     Node 6 (L): {'age': 0.0, 'size': 0.6}
#     Node 7 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 8 (L): {'age': 0.0, 'size': 0.6}
#     Node 9 (L): {'age': 0.0, 'size': 0.6}
#     Node 10 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 12 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=5] Phase 3 (Think)
# [t=5] Phase 4 (Act)
# [t=6] Phase 1 (Sense)
# [t=6] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 1 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 2 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 5 (L): {'age': 0.0, 'size': 0.7}
#     Node 6 (L): {'age': 0.0, 'size': 0.7}
#     Node 7 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 8 (L): {'age': 0.0, 'size': 0.7}
#     Node 9 (L): {'age': 0.0, 'size': 0.7}
#     Node 10 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 11 (L): {'age': 0.0, 'size': 0.4}
#     Node 12 (L): {'age': 0.0, 'size': 0.4}
# [t=6] Phase 3 (Think)
# [t=6] Phase 4 (Act)
# [t=7] Phase 1 (Sense)
# [t=7] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 1 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 2 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 5 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 6 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 7 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 8 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 9 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 10 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 11 (L): {'age': 0.0, 'size': 0.5}
#     Node 12 (L): {'age': 0.0, 'size': 0.5}
# [t=7] Phase 3 (Think)
# [t=7] Phase 4 (Act)
# [t=8] Phase 1 (Sense)
# [t=8] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 1 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 2 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 5 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 6 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 7 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 8 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 9 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 10 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 11 (L): {'age': 0.0, 'size': 0.6}
#     Node 12 (L): {'age': 0.0, 'size': 0.6}
# [t=8] Phase 3 (Think)
# [t=8] Phase 4 (Act)
# [t=9] Phase 1 (Sense)
# [t=9] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 1 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 2 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 5 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 6 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 7 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 8 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 9 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 10 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 11 (L): {'age': 0.0, 'size': 0.7}
#     Node 12 (L): {'age': 0.0, 'size': 0.7}
# [t=9] Phase 3 (Think)
# [t=9] Phase 4 (Act)
# [t=10] Phase 1 (Sense)
# [t=10] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 1 (L): {'age': 0.0, 'size': 1.2}
#     Node 2 (L): {'age': 0.0, 'size': 1.2}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 5 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 6 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 7 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 8 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 9 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 10 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 11 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 12 (L): {'age': 0.0, 'size': 0.7999999999999999}
# [t=10] Phase 3 (Think)
# [t=10] Phase 4 (Act)
# [t=11] Phase 1 (Sense)
# [t=11] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 1 (L): {'age': 0.0, 'size': 1.3}
#     Node 2 (L): {'age': 0.0, 'size': 1.3}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 5 (L): {'age': 0.0, 'size': 1.2}
#     Node 6 (L): {'age': 0.0, 'size': 1.2}
#     Node 7 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 8 (L): {'age': 0.0, 'size': 1.2}
#     Node 9 (L): {'age': 0.0, 'size': 1.2}
#     Node 10 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 11 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 12 (L): {'age': 0.0, 'size': 0.8999999999999999}
# [t=11] Phase 3 (Think)
# [t=11] Phase 4 (Act)
# [t=12] Phase 1 (Sense)
# [t=12] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 1 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 2 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 5 (L): {'age': 0.0, 'size': 1.3}
#     Node 6 (L): {'age': 0.0, 'size': 1.3}
#     Node 7 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 8 (L): {'age': 0.0, 'size': 1.3}
#     Node 9 (L): {'age': 0.0, 'size': 1.3}
#     Node 10 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 11 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 12 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 13 (S): {'age': 0.0, 'size': 1.1}
#     Node 14 (L): {'age': 0.0, 'size': 0.2}
#     Node 15 (L): {'age': 0.0, 'size': 0.2}
# [t=12] Phase 3 (Think)
# [t=12] Phase 4 (Act)
# [t=13] Phase 1 (Sense)
# [t=13] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 1 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 2 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 5 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 6 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 7 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 8 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 9 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 10 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 11 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 12 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 13 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 14 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 15 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=13] Phase 3 (Think)
# [t=13] Phase 4 (Act)
# [t=14] Phase 1 (Sense)
# [t=14] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 1 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 2 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 5 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 6 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 7 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 8 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 9 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 10 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 11 (L): {'age': 0.0, 'size': 1.2}
#     Node 12 (L): {'age': 0.0, 'size': 1.2}
#     Node 13 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 14 (L): {'age': 0.0, 'size': 0.4}
#     Node 15 (L): {'age': 0.0, 'size': 0.4}
# [t=14] Phase 3 (Think)
# [t=14] Phase 4 (Act)
# [t=15] Phase 1 (Sense)
# [t=15] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 1 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 2 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 5 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 6 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 7 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 8 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 9 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 10 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 11 (L): {'age': 0.0, 'size': 1.3}
#     Node 12 (L): {'age': 0.0, 'size': 1.3}
#     Node 13 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 14 (L): {'age': 0.0, 'size': 0.5}
#     Node 15 (L): {'age': 0.0, 'size': 0.5}
# [t=15] Phase 3 (Think)
# [t=15] Phase 4 (Act)
# [t=16] Phase 1 (Sense)
# [t=16] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 1 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 2 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 5 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 6 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 7 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 8 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 9 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 10 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 11 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 12 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 13 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 14 (L): {'age': 0.0, 'size': 0.6}
#     Node 15 (L): {'age': 0.0, 'size': 0.6}
# [t=16] Phase 3 (Think)
# [t=16] Phase 4 (Act)
# [t=17] Phase 1 (Sense)
# [t=17] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 1 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 2 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 5 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 6 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 7 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 8 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 9 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 10 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 11 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 12 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 13 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 14 (L): {'age': 0.0, 'size': 0.7}
#     Node 15 (L): {'age': 0.0, 'size': 0.7}
# [t=17] Phase 3 (Think)
# [t=17] Phase 4 (Act)
# [t=18] Phase 1 (Sense)
# [t=18] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 1 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 2 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 5 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 6 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 7 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 8 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 9 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 10 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 11 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 12 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 13 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 14 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 1.1}
#     Node 17 (L): {'age': 0.0, 'size': 0.2}
#     Node 18 (L): {'age': 0.0, 'size': 0.2}
# [t=18] Phase 3 (Think)
# [t=18] Phase 4 (Act)
# [t=19] Phase 1 (Sense)
# [t=19] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 1 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 2 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 5 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 6 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 7 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 8 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 9 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 10 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 11 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 12 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 13 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 14 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 17 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 18 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=19] Phase 3 (Think)
# [t=19] Phase 4 (Act)
# [t=20] Phase 1 (Sense)
# [t=20] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 2 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 5 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 6 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 7 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 8 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 9 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 10 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 11 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 12 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 13 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 14 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 17 (L): {'age': 0.0, 'size': 0.4}
#     Node 18 (L): {'age': 0.0, 'size': 0.4}
# [t=20] Phase 3 (Think)
# [t=20] Phase 4 (Act)
# [t=21] Phase 1 (Sense)
# [t=21] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 2 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 6 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 7 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 9 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 10 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 11 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 12 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 13 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 14 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 17 (L): {'age': 0.0, 'size': 0.5}
#     Node 18 (L): {'age': 0.0, 'size': 0.5}
# [t=21] Phase 3 (Think)
# [t=21] Phase 4 (Act)
# [t=22] Phase 1 (Sense)
# [t=22] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 2 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 6 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 7 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 9 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 10 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 11 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 12 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 13 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 14 (L): {'age': 0.0, 'size': 1.2}
#     Node 15 (L): {'age': 0.0, 'size': 1.2}
#     Node 16 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 17 (L): {'age': 0.0, 'size': 0.6}
#     Node 18 (L): {'age': 0.0, 'size': 0.6}
#     Node 19 (S): {'age': 0.0, 'size': 1.1}
#     Node 20 (L): {'age': 0.0, 'size': 0.2}
#     Node 21 (L): {'age': 0.0, 'size': 0.2}
# [t=22] Phase 3 (Think)
# [t=22] Phase 4 (Act)
# [t=23] Phase 1 (Sense)
# [t=23] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 2 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 6 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 7 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 9 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 10 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 11 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 12 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 13 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 14 (L): {'age': 0.0, 'size': 1.3}
#     Node 15 (L): {'age': 0.0, 'size': 1.3}
#     Node 16 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 17 (L): {'age': 0.0, 'size': 0.7}
#     Node 18 (L): {'age': 0.0, 'size': 0.7}
#     Node 19 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 20 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 21 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=23] Phase 3 (Think)
# [t=23] Phase 4 (Act)
# [t=24] Phase 1 (Sense)
# [t=24] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 2 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 6 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 7 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 9 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 10 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 12 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 13 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 14 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 15 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 16 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 17 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 18 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 19 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 20 (L): {'age': 0.0, 'size': 0.4}
#     Node 21 (L): {'age': 0.0, 'size': 0.4}
#     Node 22 (S): {'age': 0.0, 'size': 1.1}
#     Node 23 (L): {'age': 0.0, 'size': 0.2}
#     Node 24 (L): {'age': 0.0, 'size': 0.2}
# [t=24] Phase 3 (Think)
# [t=24] Phase 4 (Act)
# [t=25] Phase 1 (Sense)
# [t=25] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 1 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 2 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 6 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 7 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 9 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 10 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 12 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 13 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 14 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 15 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 16 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 17 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 18 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 19 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 20 (L): {'age': 0.0, 'size': 0.5}
#     Node 21 (L): {'age': 0.0, 'size': 0.5}
#     Node 22 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 23 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 24 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=25] Phase 3 (Think)
# [t=25] Phase 4 (Act)
# [t=26] Phase 1 (Sense)
# [t=26] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.7000000000000024}
#     Node 1 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 2 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 5 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 6 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 7 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 8 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 9 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 10 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 12 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 13 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 14 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 15 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 16 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 17 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 18 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 19 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 20 (L): {'age': 0.0, 'size': 0.6}
#     Node 21 (L): {'age': 0.0, 'size': 0.6}
#     Node 22 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 23 (L): {'age': 0.0, 'size': 0.4}
#     Node 24 (L): {'age': 0.0, 'size': 0.4}
#     Node 25 (S): {'age': 0.0, 'size': 1.1}
#     Node 26 (L): {'age': 0.0, 'size': 0.2}
#     Node 27 (L): {'age': 0.0, 'size': 0.2}
# [t=26] Phase 3 (Think)
# [t=26] Phase 4 (Act)
# [t=27] Phase 1 (Sense)
# [t=27] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.8000000000000025}
#     Node 1 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 2 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.7000000000000024}
#     Node 5 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 6 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 7 (S): {'age': 0.0, 'size': 3.7000000000000024}
#     Node 8 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 9 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 10 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 12 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 13 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 14 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 15 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 16 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 17 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 18 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 19 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 20 (L): {'age': 0.0, 'size': 0.7}
#     Node 21 (L): {'age': 0.0, 'size': 0.7}
#     Node 22 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 23 (L): {'age': 0.0, 'size': 0.5}
#     Node 24 (L): {'age': 0.0, 'size': 0.5}
#     Node 25 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 26 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 27 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=27] Phase 3 (Think)
# [t=27] Phase 4 (Act)
# [t=28] Phase 1 (Sense)
# [t=28] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 3.9000000000000026}
#     Node 1 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 2 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.8000000000000025}
#     Node 5 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 6 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 7 (S): {'age': 0.0, 'size': 3.8000000000000025}
#     Node 8 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 9 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 10 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 12 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 13 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 14 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 15 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 16 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 17 (L): {'age': 0.0, 'size': 1.2}
#     Node 18 (L): {'age': 0.0, 'size': 1.2}
#     Node 19 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 20 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 21 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 22 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 23 (L): {'age': 0.0, 'size': 0.6}
#     Node 24 (L): {'age': 0.0, 'size': 0.6}
#     Node 25 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 26 (L): {'age': 0.0, 'size': 0.4}
#     Node 27 (L): {'age': 0.0, 'size': 0.4}
#     Node 28 (S): {'age': 0.0, 'size': 1.1}
#     Node 29 (L): {'age': 0.0, 'size': 0.2}
#     Node 30 (L): {'age': 0.0, 'size': 0.2}
# [t=28] Phase 3 (Think)
# [t=28] Phase 4 (Act)
# [t=29] Phase 1 (Sense)
# [t=29] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.000000000000003}
#     Node 1 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 2 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 3.9000000000000026}
#     Node 5 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 6 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 7 (S): {'age': 0.0, 'size': 3.9000000000000026}
#     Node 8 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 9 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 10 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 11 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 12 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 13 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 14 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 15 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 16 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 17 (L): {'age': 0.0, 'size': 1.3}
#     Node 18 (L): {'age': 0.0, 'size': 1.3}
#     Node 19 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 20 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 21 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 22 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 23 (L): {'age': 0.0, 'size': 0.7}
#     Node 24 (L): {'age': 0.0, 'size': 0.7}
#     Node 25 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 26 (L): {'age': 0.0, 'size': 0.5}
#     Node 27 (L): {'age': 0.0, 'size': 0.5}
#     Node 28 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 29 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 30 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=29] Phase 3 (Think)
# [t=29] Phase 4 (Act)
# [t=30] Phase 1 (Sense)
# [t=30] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.100000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 2 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.000000000000003}
#     Node 5 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 6 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 7 (S): {'age': 0.0, 'size': 4.000000000000003}
#     Node 8 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 9 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 10 (S): {'age': 0.0, 'size': 3.7000000000000024}
#     Node 11 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 12 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 13 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 14 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 15 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 16 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 17 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 18 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 19 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 20 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 21 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 22 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 23 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 24 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 25 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 26 (L): {'age': 0.0, 'size': 0.6}
#     Node 27 (L): {'age': 0.0, 'size': 0.6}
#     Node 28 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 29 (L): {'age': 0.0, 'size': 0.4}
#     Node 30 (L): {'age': 0.0, 'size': 0.4}
#     Node 31 (S): {'age': 0.0, 'size': 1.1}
#     Node 32 (L): {'age': 0.0, 'size': 0.2}
#     Node 33 (L): {'age': 0.0, 'size': 0.2}
# [t=30] Phase 3 (Think)
# [t=30] Phase 4 (Act)
# [t=31] Phase 1 (Sense)
# [t=31] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.200000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 2 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.100000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 6 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 7 (S): {'age': 0.0, 'size': 4.100000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 9 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 10 (S): {'age': 0.0, 'size': 3.8000000000000025}
#     Node 11 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 12 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 13 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 14 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 15 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 16 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 17 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 18 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 19 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 20 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 21 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 22 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 23 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 24 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 25 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 26 (L): {'age': 0.0, 'size': 0.7}
#     Node 27 (L): {'age': 0.0, 'size': 0.7}
#     Node 28 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 29 (L): {'age': 0.0, 'size': 0.5}
#     Node 30 (L): {'age': 0.0, 'size': 0.5}
#     Node 31 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 32 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 33 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=31] Phase 3 (Think)
# [t=31] Phase 4 (Act)
# [t=32] Phase 1 (Sense)
# [t=32] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.300000000000002}
#     Node 1 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 2 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.200000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 6 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 7 (S): {'age': 0.0, 'size': 4.200000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 9 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 10 (S): {'age': 0.0, 'size': 3.9000000000000026}
#     Node 11 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 12 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 13 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 14 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 15 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 16 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 17 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 18 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 19 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 20 (L): {'age': 0.0, 'size': 1.2}
#     Node 21 (L): {'age': 0.0, 'size': 1.2}
#     Node 22 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 23 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 24 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 25 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 26 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 27 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 28 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 29 (L): {'age': 0.0, 'size': 0.6}
#     Node 30 (L): {'age': 0.0, 'size': 0.6}
#     Node 31 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 32 (L): {'age': 0.0, 'size': 0.4}
#     Node 33 (L): {'age': 0.0, 'size': 0.4}
#     Node 34 (S): {'age': 0.0, 'size': 1.1}
#     Node 35 (L): {'age': 0.0, 'size': 0.2}
#     Node 36 (L): {'age': 0.0, 'size': 0.2}
# [t=32] Phase 3 (Think)
# [t=32] Phase 4 (Act)
# [t=33] Phase 1 (Sense)
# [t=33] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.400000000000001}
#     Node 1 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 2 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.300000000000002}
#     Node 5 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 6 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 7 (S): {'age': 0.0, 'size': 4.300000000000002}
#     Node 8 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 9 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 10 (S): {'age': 0.0, 'size': 4.000000000000003}
#     Node 11 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 12 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 13 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 14 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 15 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 16 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 17 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 18 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 19 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 20 (L): {'age': 0.0, 'size': 1.3}
#     Node 21 (L): {'age': 0.0, 'size': 1.3}
#     Node 22 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 23 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 24 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 25 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 26 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 27 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 28 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 29 (L): {'age': 0.0, 'size': 0.7}
#     Node 30 (L): {'age': 0.0, 'size': 0.7}
#     Node 31 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 32 (L): {'age': 0.0, 'size': 0.5}
#     Node 33 (L): {'age': 0.0, 'size': 0.5}
#     Node 34 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 35 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 36 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=33] Phase 3 (Think)
# [t=33] Phase 4 (Act)
# [t=34] Phase 1 (Sense)
# [t=34] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.500000000000001}
#     Node 1 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 2 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.400000000000001}
#     Node 5 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 6 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 7 (S): {'age': 0.0, 'size': 4.400000000000001}
#     Node 8 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 9 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 10 (S): {'age': 0.0, 'size': 4.100000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 12 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 13 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 14 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 15 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 16 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 17 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 18 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 19 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 20 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 21 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 22 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 23 (L): {'age': 0.0, 'size': 1.2}
#     Node 24 (L): {'age': 0.0, 'size': 1.2}
#     Node 25 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 26 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 27 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 28 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 29 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 30 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 31 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 32 (L): {'age': 0.0, 'size': 0.6}
#     Node 33 (L): {'age': 0.0, 'size': 0.6}
#     Node 34 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 35 (L): {'age': 0.0, 'size': 0.4}
#     Node 36 (L): {'age': 0.0, 'size': 0.4}
#     Node 37 (S): {'age': 0.0, 'size': 1.1}
#     Node 38 (L): {'age': 0.0, 'size': 0.2}
#     Node 39 (L): {'age': 0.0, 'size': 0.2}
# [t=34] Phase 3 (Think)
# [t=34] Phase 4 (Act)
# [t=35] Phase 1 (Sense)
# [t=35] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.6000000000000005}
#     Node 1 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 2 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.500000000000001}
#     Node 5 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 6 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 7 (S): {'age': 0.0, 'size': 4.500000000000001}
#     Node 8 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 9 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 10 (S): {'age': 0.0, 'size': 4.200000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 12 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 13 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 14 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 15 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 16 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 17 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 18 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 19 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 20 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 21 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 22 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 23 (L): {'age': 0.0, 'size': 1.3}
#     Node 24 (L): {'age': 0.0, 'size': 1.3}
#     Node 25 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 26 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 27 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 28 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 29 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 30 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 31 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 32 (L): {'age': 0.0, 'size': 0.7}
#     Node 33 (L): {'age': 0.0, 'size': 0.7}
#     Node 34 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 35 (L): {'age': 0.0, 'size': 0.5}
#     Node 36 (L): {'age': 0.0, 'size': 0.5}
#     Node 37 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 38 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 39 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=35] Phase 3 (Think)
# [t=35] Phase 4 (Act)
# [t=36] Phase 1 (Sense)
# [t=36] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.7}
#     Node 1 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 2 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.6000000000000005}
#     Node 5 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 6 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 7 (S): {'age': 0.0, 'size': 4.6000000000000005}
#     Node 8 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 9 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 10 (S): {'age': 0.0, 'size': 4.300000000000002}
#     Node 11 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 12 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 13 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 14 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 15 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 16 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 17 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 18 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 19 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 20 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 21 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 22 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 23 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 24 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 25 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 26 (L): {'age': 0.0, 'size': 1.2}
#     Node 27 (L): {'age': 0.0, 'size': 1.2}
#     Node 28 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 29 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 30 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 31 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 32 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 33 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 34 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 35 (L): {'age': 0.0, 'size': 0.6}
#     Node 36 (L): {'age': 0.0, 'size': 0.6}
#     Node 37 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 38 (L): {'age': 0.0, 'size': 0.4}
#     Node 39 (L): {'age': 0.0, 'size': 0.4}
#     Node 40 (S): {'age': 0.0, 'size': 1.1}
#     Node 41 (L): {'age': 0.0, 'size': 0.2}
#     Node 42 (L): {'age': 0.0, 'size': 0.2}
# [t=36] Phase 3 (Think)
# [t=36] Phase 4 (Act)
# [t=37] Phase 1 (Sense)
# [t=37] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 4.8}
#     Node 1 (L): {'age': 0.0, 'size': 3.900000000000002}
#     Node 2 (L): {'age': 0.0, 'size': 3.900000000000002}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 4.7}
#     Node 5 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 6 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 7 (S): {'age': 0.0, 'size': 4.7}
#     Node 8 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 9 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 10 (S): {'age': 0.0, 'size': 4.400000000000001}
#     Node 11 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 12 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 13 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 14 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 15 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 16 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 17 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 18 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 19 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 20 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 21 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 22 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 23 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 24 (L): {'age': 0.0, 'size': 1.5000000000000002}
# ...
#     Node 9 (L): {'age': 0.0, 'size': 5.699999999999996}
#     Node 10 (S): {'age': 0.0, 'size': 6.2999999999999945}
#     Node 11 (L): {'age': 0.0, 'size': 5.399999999999997}
#     Node 12 (L): {'age': 0.0, 'size': 5.399999999999997}
#     Node 13 (S): {'age': 0.0, 'size': 5.499999999999997}
#     Node 14 (L): {'age': 0.0, 'size': 4.6}
#     Node 15 (L): {'age': 0.0, 'size': 4.6}
#     Node 16 (S): {'age': 0.0, 'size': 4.8999999999999995}
#     Node 17 (L): {'age': 0.0, 'size': 4.000000000000002}
#     Node 18 (L): {'age': 0.0, 'size': 4.000000000000002}
#     Node 19 (S): {'age': 0.0, 'size': 4.500000000000001}
#     Node 20 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 21 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 22 (S): {'age': 0.0, 'size': 4.300000000000002}
#     Node 23 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 24 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 25 (S): {'age': 0.0, 'size': 4.100000000000002}
#     Node 26 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 27 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 28 (S): {'age': 0.0, 'size': 3.9000000000000026}
#     Node 29 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 30 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 31 (S): {'age': 0.0, 'size': 3.7000000000000024}
#     Node 32 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 33 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 34 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 35 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 36 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 37 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 38 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 39 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 40 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 41 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 42 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 43 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 44 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 45 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 46 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 47 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 48 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 49 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 50 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 51 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 52 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 53 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 54 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 55 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 56 (L): {'age': 0.0, 'size': 1.2}
#     Node 57 (L): {'age': 0.0, 'size': 1.2}
#     Node 58 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 59 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 60 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 61 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 62 (L): {'age': 0.0, 'size': 0.7}
#     Node 63 (L): {'age': 0.0, 'size': 0.7}
#     Node 64 (S): {'age': 0.0, 'size': 1.3000000000000003}
#     Node 65 (L): {'age': 0.0, 'size': 0.4}
#     Node 66 (L): {'age': 0.0, 'size': 0.4}
# [t=56] Phase 3 (Think)
# [t=56] Phase 4 (Act)
# [t=57] Phase 1 (Sense)
# [t=57] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 6.799999999999993}
#     Node 1 (L): {'age': 0.0, 'size': 5.899999999999995}
#     Node 2 (L): {'age': 0.0, 'size': 5.899999999999995}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 6.699999999999993}
#     Node 5 (L): {'age': 0.0, 'size': 5.799999999999995}
#     Node 6 (L): {'age': 0.0, 'size': 5.799999999999995}
#     Node 7 (S): {'age': 0.0, 'size': 6.699999999999993}
#     Node 8 (L): {'age': 0.0, 'size': 5.799999999999995}
#     Node 9 (L): {'age': 0.0, 'size': 5.799999999999995}
#     Node 10 (S): {'age': 0.0, 'size': 6.399999999999994}
#     Node 11 (L): {'age': 0.0, 'size': 5.4999999999999964}
#     Node 12 (L): {'age': 0.0, 'size': 5.4999999999999964}
#     Node 13 (S): {'age': 0.0, 'size': 5.599999999999997}
#     Node 14 (L): {'age': 0.0, 'size': 4.699999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 4.699999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 4.999999999999999}
#     Node 17 (L): {'age': 0.0, 'size': 4.100000000000001}
#     Node 18 (L): {'age': 0.0, 'size': 4.100000000000001}
#     Node 19 (S): {'age': 0.0, 'size': 4.6000000000000005}
#     Node 20 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 21 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 22 (S): {'age': 0.0, 'size': 4.400000000000001}
#     Node 23 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 24 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 25 (S): {'age': 0.0, 'size': 4.200000000000002}
#     Node 26 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 27 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 28 (S): {'age': 0.0, 'size': 4.000000000000003}
#     Node 29 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 30 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 31 (S): {'age': 0.0, 'size': 3.8000000000000025}
#     Node 32 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 33 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 34 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 35 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 36 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 37 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 38 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 39 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 40 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 41 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 42 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 43 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 44 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 45 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 46 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 47 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 48 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 49 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 50 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 51 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 52 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 53 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 54 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 55 (S): {'age': 0.0, 'size': 2.200000000000001}
#     Node 56 (L): {'age': 0.0, 'size': 1.3}
#     Node 57 (L): {'age': 0.0, 'size': 1.3}
#     Node 58 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 59 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 60 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 61 (S): {'age': 0.0, 'size': 1.7000000000000006}
#     Node 62 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 63 (L): {'age': 0.0, 'size': 0.7999999999999999}
#     Node 64 (S): {'age': 0.0, 'size': 1.4000000000000004}
#     Node 65 (L): {'age': 0.0, 'size': 0.5}
#     Node 66 (L): {'age': 0.0, 'size': 0.5}
# [t=57] Phase 3 (Think)
# [t=57] Phase 4 (Act)
# [t=58] Phase 1 (Sense)
# [t=58] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 6.899999999999992}
#     Node 1 (L): {'age': 0.0, 'size': 5.999999999999995}
#     Node 2 (L): {'age': 0.0, 'size': 5.999999999999995}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 6.799999999999993}
#     Node 5 (L): {'age': 0.0, 'size': 5.899999999999995}
#     Node 6 (L): {'age': 0.0, 'size': 5.899999999999995}
#     Node 7 (S): {'age': 0.0, 'size': 6.799999999999993}
#     Node 8 (L): {'age': 0.0, 'size': 5.899999999999995}
#     Node 9 (L): {'age': 0.0, 'size': 5.899999999999995}
#     Node 10 (S): {'age': 0.0, 'size': 6.499999999999994}
#     Node 11 (L): {'age': 0.0, 'size': 5.599999999999996}
#     Node 12 (L): {'age': 0.0, 'size': 5.599999999999996}
#     Node 13 (S): {'age': 0.0, 'size': 5.699999999999997}
#     Node 14 (L): {'age': 0.0, 'size': 4.799999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 4.799999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 5.099999999999999}
#     Node 17 (L): {'age': 0.0, 'size': 4.200000000000001}
#     Node 18 (L): {'age': 0.0, 'size': 4.200000000000001}
#     Node 19 (S): {'age': 0.0, 'size': 4.7}
#     Node 20 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 21 (L): {'age': 0.0, 'size': 3.800000000000002}
#     Node 22 (S): {'age': 0.0, 'size': 4.500000000000001}
#     Node 23 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 24 (L): {'age': 0.0, 'size': 3.600000000000002}
#     Node 25 (S): {'age': 0.0, 'size': 4.300000000000002}
#     Node 26 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 27 (L): {'age': 0.0, 'size': 3.4000000000000017}
#     Node 28 (S): {'age': 0.0, 'size': 4.100000000000002}
#     Node 29 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 30 (L): {'age': 0.0, 'size': 3.2000000000000015}
#     Node 31 (S): {'age': 0.0, 'size': 3.9000000000000026}
#     Node 32 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 33 (L): {'age': 0.0, 'size': 3.0000000000000013}
#     Node 34 (S): {'age': 0.0, 'size': 3.7000000000000024}
#     Node 35 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 36 (L): {'age': 0.0, 'size': 2.800000000000001}
#     Node 37 (S): {'age': 0.0, 'size': 3.500000000000002}
#     Node 38 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 39 (L): {'age': 0.0, 'size': 2.600000000000001}
#     Node 40 (S): {'age': 0.0, 'size': 3.300000000000002}
#     Node 41 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 42 (L): {'age': 0.0, 'size': 2.400000000000001}
#     Node 43 (S): {'age': 0.0, 'size': 3.100000000000002}
#     Node 44 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 45 (L): {'age': 0.0, 'size': 2.2000000000000006}
#     Node 46 (S): {'age': 0.0, 'size': 2.9000000000000017}
#     Node 47 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 48 (L): {'age': 0.0, 'size': 2.0000000000000004}
#     Node 49 (S): {'age': 0.0, 'size': 2.7000000000000015}
#     Node 50 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 51 (L): {'age': 0.0, 'size': 1.8000000000000005}
#     Node 52 (S): {'age': 0.0, 'size': 2.5000000000000013}
#     Node 53 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 54 (L): {'age': 0.0, 'size': 1.6000000000000003}
#     Node 55 (S): {'age': 0.0, 'size': 2.300000000000001}
#     Node 56 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 57 (L): {'age': 0.0, 'size': 1.4000000000000001}
#     Node 58 (S): {'age': 0.0, 'size': 2.000000000000001}
#     Node 59 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 60 (L): {'age': 0.0, 'size': 1.0999999999999999}
#     Node 61 (S): {'age': 0.0, 'size': 1.8000000000000007}
#     Node 62 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 63 (L): {'age': 0.0, 'size': 0.8999999999999999}
#     Node 64 (S): {'age': 0.0, 'size': 1.5000000000000004}
#     Node 65 (L): {'age': 0.0, 'size': 0.6}
#     Node 66 (L): {'age': 0.0, 'size': 0.6}
#     Node 67 (S): {'age': 0.0, 'size': 1.1}
#     Node 68 (L): {'age': 0.0, 'size': 0.2}
#     Node 69 (L): {'age': 0.0, 'size': 0.2}
# [t=58] Phase 3 (Think)
# [t=58] Phase 4 (Act)
# [t=59] Phase 1 (Sense)
# [t=59] Phase 2 (Evolve): applying dynamics to all agents.
#     Node 0 (S): {'age': 0.0, 'size': 6.999999999999992}
#     Node 1 (L): {'age': 0.0, 'size': 6.099999999999994}
#     Node 2 (L): {'age': 0.0, 'size': 6.099999999999994}
#     Node 3 (SAM): {'age': 0.0}
#     Node 4 (S): {'age': 0.0, 'size': 6.899999999999992}
#     Node 5 (L): {'age': 0.0, 'size': 5.999999999999995}
#     Node 6 (L): {'age': 0.0, 'size': 5.999999999999995}
#     Node 7 (S): {'age': 0.0, 'size': 6.899999999999992}
#     Node 8 (L): {'age': 0.0, 'size': 5.999999999999995}
#     Node 9 (L): {'age': 0.0, 'size': 5.999999999999995}
#     Node 10 (S): {'age': 0.0, 'size': 6.599999999999993}
#     Node 11 (L): {'age': 0.0, 'size': 5.699999999999996}
#     Node 12 (L): {'age': 0.0, 'size': 5.699999999999996}
#     Node 13 (S): {'age': 0.0, 'size': 5.799999999999996}
#     Node 14 (L): {'age': 0.0, 'size': 4.899999999999999}
#     Node 15 (L): {'age': 0.0, 'size': 4.899999999999999}
#     Node 16 (S): {'age': 0.0, 'size': 5.199999999999998}
#     Node 17 (L): {'age': 0.0, 'size': 4.300000000000001}
#     Node 18 (L): {'age': 0.0, 'size': 4.300000000000001}
#     Node 19 (S): {'age': 0.0, 'size': 4.8}
#     Node 20 (L): {'age': 0.0, 'size': 3.900000000000002}
#     Node 21 (L): {'age': 0.0, 'size': 3.900000000000002}
#     Node 22 (S): {'age': 0.0, 'size': 4.6000000000000005}
#     Node 23 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 24 (L): {'age': 0.0, 'size': 3.700000000000002}
#     Node 25 (S): {'age': 0.0, 'size': 4.400000000000001}
#     Node 26 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 27 (L): {'age': 0.0, 'size': 3.5000000000000018}
#     Node 28 (S): {'age': 0.0, 'size': 4.200000000000002}
#     Node 29 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 30 (L): {'age': 0.0, 'size': 3.3000000000000016}
#     Node 31 (S): {'age': 0.0, 'size': 4.000000000000003}
#     Node 32 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 33 (L): {'age': 0.0, 'size': 3.1000000000000014}
#     Node 34 (S): {'age': 0.0, 'size': 3.8000000000000025}
#     Node 35 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 36 (L): {'age': 0.0, 'size': 2.9000000000000012}
#     Node 37 (S): {'age': 0.0, 'size': 3.6000000000000023}
#     Node 38 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 39 (L): {'age': 0.0, 'size': 2.700000000000001}
#     Node 40 (S): {'age': 0.0, 'size': 3.400000000000002}
#     Node 41 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 42 (L): {'age': 0.0, 'size': 2.500000000000001}
#     Node 43 (S): {'age': 0.0, 'size': 3.200000000000002}
#     Node 44 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 45 (L): {'age': 0.0, 'size': 2.3000000000000007}
#     Node 46 (S): {'age': 0.0, 'size': 3.0000000000000018}
#     Node 47 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 48 (L): {'age': 0.0, 'size': 2.1000000000000005}
#     Node 49 (S): {'age': 0.0, 'size': 2.8000000000000016}
#     Node 50 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 51 (L): {'age': 0.0, 'size': 1.9000000000000006}
#     Node 52 (S): {'age': 0.0, 'size': 2.6000000000000014}
#     Node 53 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 54 (L): {'age': 0.0, 'size': 1.7000000000000004}
#     Node 55 (S): {'age': 0.0, 'size': 2.4000000000000012}
#     Node 56 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 57 (L): {'age': 0.0, 'size': 1.5000000000000002}
#     Node 58 (S): {'age': 0.0, 'size': 2.100000000000001}
#     Node 59 (L): {'age': 0.0, 'size': 1.2}
#     Node 60 (L): {'age': 0.0, 'size': 1.2}
#     Node 61 (S): {'age': 0.0, 'size': 1.9000000000000008}
#     Node 62 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 63 (L): {'age': 0.0, 'size': 0.9999999999999999}
#     Node 64 (S): {'age': 0.0, 'size': 1.6000000000000005}
#     Node 65 (L): {'age': 0.0, 'size': 0.7}
#     Node 66 (L): {'age': 0.0, 'size': 0.7}
#     Node 67 (S): {'age': 0.0, 'size': 1.2000000000000002}
#     Node 68 (L): {'age': 0.0, 'size': 0.30000000000000004}
#     Node 69 (L): {'age': 0.0, 'size': 0.30000000000000004}
# [t=59] Phase 3 (Think)
# [t=59] Phase 4 (Act)
# === Simulation complete.
#
# --- Average Phase Times (per step) ---
#   Sense: 0.0000 sec
#  Evolve: 0.0003 sec
#   Think: 0.0006 sec
#     Act: 0.0000 sec
# tensor([ 2.6193,  2.7493,  2.8807,  3.0132,  3.1464,  3.2806,  3.4155,  3.5509,
#          3.6870,  3.8235,  3.9604,  4.0977,  4.2352,  4.3731,  4.5113,  4.6496,
#          4.8639,  5.1417,  5.4217,  5.7004,  5.9793,  6.4097,  6.8845,  7.3016,
#          7.7631,  8.1718,  8.6334,  9.0683,  9.5893, 10.0571, 10.5855, 11.0599,
#         11.5883, 12.0627, 12.5911, 13.0655, 13.5940, 14.0683, 14.5968, 15.0711,
#         15.5996, 16.0732, 16.5992, 17.0714, 17.5853, 18.0060, 18.5179, 18.9386,
#         19.3594, 19.8713, 20.1355, 20.6127, 20.8636, 21.1145, 21.5866, 21.7428,
#         21.8990, 22.0552, 22.4761, 22.6323], grad_fn=<CatBackward0>)
